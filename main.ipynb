# %%
#解压数据
# !unzip -d data/data117189/train_img/ -q data/data117189/PLAM.zip
# !unzip -d data/data117189/test_img/ -q data/data117189/Testing400.zip

# %%
# 导出CSV
# !rm -rf ./Fovea_Localization_Results.csv
# !python widerface_eval_dir.py --image_dir=data/data117189/test_img/Testing400 --use_gpu=True --class_num=1 --model_dir=train_model/PLAM/pre_model --label_name_list='火''烟' --confs_threshold=0.23
# Out:
# -----------  Configuration Arguments -----------
# class_num: 1
# confs_threshold: 0.23
# data_dir:
# file_list:
# image_dir: data/data117189/test_img/Testing400
# infer: True
# label_name_list: ['火', '烟']
# model_dir: train_model/PLAM/pre_model
# pred_dir:
# use_gpu: 1
# use_pyramidbox: True
# ------------------------------------------------
# /opt/conda/envs/python35-paddle120-env/lib/python3.7/site-packages/paddle/fluid/layers/math_op_patch.py:341: UserWarning: /home/aistudio/pyramidbox.py:182
# The behavior of expression A * B has been unified with elementwise_mul(X, Y, axis=-1) from Paddle 2.0. If your code works well in the older versions but crashes in this version, try to use elementwise_mul(X, Y, axis=0) instead of A * B. This transitional warning will be dropped in the future.
#   op_type, op_type, EXPRESSION_MAP[method_name]))
# ...

# %%
#测试训练模型
# !rm -rf infer_result/*
# !rm -rf ./test_img/.ipynb_checkpoints
# !python widerface_eval_dir.py --image_dir=test_img --class_num=1 --model_dir=train_model/PLAM/pre_model --label_name_list='火''烟' --confs_threshold=0.23
import cv2 as cv
import os
# !rm -rf ./infer_result/.ipynb_checkpoints
dir_name = './infer_result'
name_list = os.listdir(dir_name)
for img_name in name_list:
    img_path = os.path.join(dir_name,img_name)
    img_np = cv.imread(img_path)
    print(name_list)
    save_np = cv.resize(img_np,(0,0),fx=0.25,fy=0.25)
    cv.imwrite(img_path,save_np)

# %%
# !nvidia-smi
# !zip -r train_model.zip ./train_model/*

# %% [markdown]
# 请点击[此处](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576)查看本环境基本用法.  <br>
# Please click [here ](https://ai.baidu.com/docs#/AIStudio_Project_Notebook/a38e5576) for more detailed instructions.
